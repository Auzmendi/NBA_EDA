# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %% [markdown]
# En este jupyter voy a hacer una primera aproximación al csv de resumen de partidos. En caso de que me valgan los datos pasaré a hacer el DC

# %% [markdown]
# # 1. Lectura del dataset y primeras comprobaciones

# %%
game_sum_df = pd.read_csv('datasets/game_summary.csv')
game_sum_df.sample(10)
# Out:
#              game_date_est  game_sequence   game_id  game_status_id  \
# 40621  2008-04-29 00:00:00            4.0  40700175               3
# 44226  2011-03-25 00:00:00            2.0  21001069               3
# 37912  2006-04-07 00:00:00            0.0  20501123               3
# 14132  1983-01-28 00:00:00            NaN  28200504               3
# 14546  1983-10-28 00:00:00            NaN  28300005               3
# 30998  2000-03-08 00:00:00            5.0  29900870               3
# 838    1949-11-16 00:00:00            NaN  24900063               3
# 57127  2022-11-27 00:00:00            9.0  22200298               3
# 55184  2021-04-12 00:00:00            2.0  22000818               3
# 54062  2020-01-30 00:00:00            6.0  21900719               3
#
#       game_status_text         gamecode  home_team_id  visitor_team_id  \
# 40621            Final  20080429/UTAHOU    1610612745       1610612762
# 44226            Final  20110325/NJNORL    1610612753       1610612751
# ...

# %%
game_sum_df.head()
# Out:
#          game_date_est  game_sequence   game_id  game_status_id  \
# 0  1946-11-01 00:00:00            NaN  24600001               3
# 1  1946-11-02 00:00:00            NaN  24600003               3
# 2  1946-11-02 00:00:00            NaN  24600002               3
# 3  1946-11-02 00:00:00            NaN  24600004               3
# 4  1946-11-02 00:00:00            NaN  24600005               3
#
#   game_status_text         gamecode  home_team_id  visitor_team_id  season  \
# 0              NaN  19461101/NYKHUS    1610610035       1610612752    1946
# 1              NaN  19461102/PITBOM    1610610034       1610610031    1946
# 2              NaN  19461102/BOSPRO    1610610032       1610612738    1946
# 3              NaN  19461102/NYKCHS    1610610025       1610612752    1946
# 4              NaN  19461102/WASDEF    1610610028       1610610036    1946
#
#    live_period live_pc_time natl_tv_broadcaster_abbreviation  \
# 0            5          NaN                              NaN
# ...

# %%
game_sum_df.shape
# Out:
# (58110, 14)

# %%
game_sum_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58110 entries, 0 to 58109
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   game_date_est                     58110 non-null  object
#  1   game_sequence                     32578 non-null  float64
#  2   game_id                           58110 non-null  int64
#  3   game_status_id                    58110 non-null  int64
#  4   game_status_text                  32124 non-null  object
#  5   gamecode                          58110 non-null  object
#  6   home_team_id                      58110 non-null  int64
#  7   visitor_team_id                   58110 non-null  int64
#  8   season                            58110 non-null  int64
#  9   live_period                       58110 non-null  int64
#  10  live_pc_time                      2024 non-null   object
# ...

# %% [markdown]
# ## Conclusión

# %% [markdown]
# No parece que me vaya a ser útil.
